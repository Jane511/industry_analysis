# %% [markdown]
# # 03 APRA RBA Arrears Environment
#
# Purpose:
#
# - inspect the staged RBA cash-rate backdrop
# - document the optional staged RBA and APRA context extracts
# - explain the qualitative arrears fallback used when those extracts are absent
