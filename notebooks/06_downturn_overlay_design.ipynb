# %% [markdown]
# # 06 Downturn Overlay Design
#
# Purpose:
#
# - explain how the arrears backdrop and cycle softness anchor the illustrative scenarios
# - document why the scenario multipliers are portfolio assumptions rather than calibrated stresses
# - inspect the final `property_downturn_overlays.csv`
