# %% [markdown]
# # 04 Region Risk Banding
#
# Purpose:
#
# - explain the region and property-segment banding logic
# - trace `region_risk_score` back to approvals, activity, finance, and structural signals
# - inspect the final `region_risk_table.csv`
