# %% [markdown]
# # 05 Property Cycle Banding
#
# Purpose:
#
# - inspect the approvals and activity signals feeding cycle staging
# - explain `growth`, `neutral`, `slowing`, and `downturn`
# - inspect the final `property_cycle_table.csv`
