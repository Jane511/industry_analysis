# %% [markdown]
# # 01 Project Overview
#
# Purpose:
#
# - explain the reference-layer role of the repo
# - list the staged public datasets currently available locally
# - show the final output architecture under `data/output/`
# - show how downstream PD, LGD, and EL repos should consume the outputs
