# %% [markdown]
# # 02 ABS Property Data Processing
#
# Purpose:
#
# - inspect staged ABS approvals inputs
# - describe how optional building-activity and lending-indicator extracts should be staged
# - explain the processed summaries written to `data/processed/property/`
