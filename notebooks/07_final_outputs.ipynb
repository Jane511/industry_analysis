# %% [markdown]
# # 07 Final Outputs
#
# Purpose:
#
# - inspect the final output files under `data/output/`
# - confirm the join keys and downstream use cases for PD, LGD, and EL repos
# - review the staged-input availability summary under `data/processed/property/`
