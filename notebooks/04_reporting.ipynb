# %% [markdown]
# # industry_analysis - Reporting
#
# Standard notebook placeholder for the rebuilt industry_analysis workflow.

# %%
from src.codex_run_pipeline import run_pipeline
result = run_pipeline(persist=True)
result["validation"].head()
